# %%
from toolbox import sq_ana as sa 
import importlib
importlib.reload(sa)
import pandas as pd

file_path = r"D:\VScode\bipolar_seesaw_CCM\other_data\monsoon.xlsx"
df = pd.read_excel(file_path)
df['age'] = df['age'] * 1000

new_df, df_sq, best = sa.build_DO_sq(df,  extra_sm=5, if_plot=True, dir='gt',metrics='F1')
# Out:
# Window 500 → min=-1.934, max=2.075
# Window 600 → min=-1.896, max=2.084
# Window 700 → min=-1.878, max=2.000
# Window 800 → min=-1.936, max=1.884
# Window 900 → min=-1.886, max=1.920
# Window 1000 → min=-1.811, max=1.953
# Window 1100 → min=-1.769, max=2.031
# Window 1200 → min=-1.796, max=2.124
# Window 1300 → min=-1.795, max=2.188
# Window 1400 → min=-1.829, max=2.226
# Window 1500 → min=-1.894, max=2.217
# Window 1600 → min=-1.935, max=2.200
# Window 1700 → min=-1.972, max=2.180
# Window 1800 → min=-2.024, max=2.176
# Window 1900 → min=-2.077, max=2.214
# Window 2000 → min=-2.162, max=2.250
# Window 2100 → min=-2.226, max=2.279
# Window 2200 → min=-2.250, max=2.301
# Window 2300 → min=-2.275, max=2.368
# Window 2400 → min=-2.288, max=2.427
# Window 2500 → min=-2.300, max=2.488
# Window 2600 → min=-2.324, max=2.542
# Window 2700 → min=-2.358, max=2.571
# Window 2800 → min=-2.371, max=2.567
# Window 2900 → min=-2.393, max=2.562
# Window 3000 → min=-2.419, max=2.557
# Window 3100 → min=-2.431, max=2.534
# Window 3200 → min=-2.437, max=2.511
# Window 3300 → min=-2.435, max=2.488
# Window 3400 → min=-2.434, max=2.459
# Window 3500 → min=-2.425, max=2.424
# Window 3600 → min=-2.406, max=2.417
# Window 3700 → min=-2.386, max=2.450
# Window 3800 → min=-2.369, max=2.481
# Window 3900 → min=-2.355, max=2.501
# Window 4000 → min=-2.343, max=2.510
# Window 4100 → min=-2.333, max=2.525
# Window 4200 → min=-2.325, max=2.536
# Window 4300 → min=-2.319, max=2.542
# Window 4400 → min=-2.312, max=2.555
# Window 4500 → min=-2.306, max=2.567
# Window 4600 → min=-2.307, max=2.578
# Window 4700 → min=-2.291, max=2.574
# Window 4800 → min=-2.273, max=2.571
# Window 4900 → min=-2.255, max=2.573
# Window 5000 → min=-2.230, max=2.578
# Window 5100 → min=-2.206, max=2.589
# Window 5200 → min=-2.199, max=2.594
# Window 5300 → min=-2.212, max=2.598
# Window 5400 → min=-2.229, max=2.604
# Window 5500 → min=-2.235, max=2.611
# Window 5600 → min=-2.233, max=2.620
# Window 5700 → min=-2.231, max=2.630
# Window 5800 → min=-2.239, max=2.641
# Window 5900 → min=-2.248, max=2.650
# Window 6000 → min=-2.264, max=2.656
# → optimal window=5700, threshold gt -0.238, max F1=0.758

# %%
from toolbox import sq_ana as sa 
import importlib
importlib.reload(sa)

df_sq, df_pre, df_obl = sa.interpolate_data_forcing(df_sq, 10, if_plot=True)
print(df_sq)
print(df_pre)
# print the length of df_sq_rs and df_pre_rs
print('Length of df_sq_rs:', len(df_sq))
# Out:
#           age   sq
# 0           0  1.0
# 1          10  1.0
# 2          20  1.0
# 3          30  1.0
# 4          40  1.0
# ...       ...  ...
# 64121  641210  1.0
# 64122  641220  1.0
# 64123  641230  1.0
# 64124  641240  1.0
# 64125  641250  1.0
#
# [64126 rows x 2 columns]
#           age       pre
# 0           0  0.016280
# 1          10  0.016280
# 2          20  0.016280
# 3          30  0.016280
# 4          40  0.016280
# ...       ...       ...
# 64121  641210 -0.005173
# 64122  641220 -0.005173
# 64123  641230 -0.005173
# 64124  641240 -0.005173
# 64125  641250 -0.005173
#
# [64126 rows x 2 columns]
# Length of df_sq_rs: 64126

# %%
from toolbox import sq_ana as sa 
import importlib
importlib.reload(sa)

pre = df_pre['pre'].values      # source (precession)

sa.plot_aic_delta(pre)

# %%
from toolbox import sq_ana as sa 
import importlib
importlib.reload(sa)


pre = df_pre['pre'].values      # source (precession)
sq = df_sq['sq'].values    # target (residual)


result =sa.transfer_entropy_surrogate_test(pre,sq,forcing_bins=3)
result
# Out:
# True
